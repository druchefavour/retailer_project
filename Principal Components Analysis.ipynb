# %%
from __future__ import division

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## 19.0.1 Data Import¶
# We will now import the dataset.

# %%
# load the master_dataset.xls
df = pd.read_excel('master_dataset.xlsx', sheetname='Sheet1')
# Print the `digits` data 
print(df.head())
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-05-02        42.31       2.572    10382.9    6115.67     215.07
# 1      1 2010-12-02        38.51       2.548    10382.9    6115.67     215.07
# 2      1 2010-02-19        39.93       2.514    10382.9    6115.67     215.07
# 3      1 2010-02-26        46.63       2.561    10382.9    6115.67     215.07
# 4      1 2010-05-03        46.50       2.625    10382.9    6115.67     215.07
#
#    MarkDown4  MarkDown5         CPI     ...          Books  \
# 0    2406.62    6551.42  211.096358     ...       73315.81
# 1    2406.62    6551.42  211.242170     ...       77280.42
# 2    2406.62    6551.42  211.289143     ...       78602.71
# 3    2406.62    6551.42  211.319643     ...       76091.36
# 4    2406.62    6551.42  211.350143     ...       71718.48
#
#   Musical_Instruments  Star_Wars  Movies_TV  Video_Games  Portable_Audios  \
# ...

# %%
# Get the keys of the `digits` data
print(df.keys())
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday', 'Type', 'Size', 'Jewelry', 'Pets', 'TV_Video',
#        'Cell_Phones', 'Pharmaceutical ', 'Health_beauty', 'Toy ',
#        'Home_others', 'Kitchen', 'Bedding', 'Bathroom', 'Office_supplies ',
#        'School_Supplies', 'Home_Office', 'Craft_general', 'Floral', 'Beading',
#        'Paint', 'Framing', 'outdoor', 'Auto', 'School_Uniforms',
#        'Baby_Toddlers_Clothing', 'Baby_Kids_Shoes', 'Clearance_Clothings',
#        'Boys_Clothing', 'Girls_Clothing', 'Women_Clothing',
#        'Intimates_Sleepwears', 'Men_Clothings', 'Precious_Metals',
#        'Active_Wear', 'Adult_Shoes', 'Bags_Accessories', 'Sportswear',
#        'Computer', 'Music', 'Luggage', 'Food', 'Fruit', 'Grocery', 'Laundry',
#        'IPad_Tablets', 'Heating_Cooling', 'Swim_Shop', 'Gift_cards',
# ...

# %%
target=df['Type'].values

# %%
# Drop "Markdown1"
df.drop(['Type'],  axis = 1, inplace=True)

# %%
# Drop Non-numeric cells
df.dropna()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-05-02        42.31       2.572   10382.90    6115.67
# 1         1 2010-12-02        38.51       2.548   10382.90    6115.67
# 2         1 2010-02-19        39.93       2.514   10382.90    6115.67
# 3         1 2010-02-26        46.63       2.561   10382.90    6115.67
# 4         1 2010-05-03        46.50       2.625   10382.90    6115.67
# 5         1 2010-12-03        57.79       2.667   10382.90    6115.67
# 6         1 2010-03-19        54.58       2.720   10382.90    6115.67
# 7         1 2010-03-26        51.45       2.732   10382.90    6115.67
# 8         1 2010-02-04        62.27       2.719   10382.90    6115.67
# 9         1 2010-09-04        65.86       2.770   10382.90    6115.67
# 10        1 2010-04-16        66.32       2.808   10382.90    6115.67
# 11        1 2010-04-23        64.84       2.795   10382.90    6115.67
# ...

# %%
# Drop "Markdown1"
df.drop(['Date'],  axis = 1, inplace=True)

# %%
data = df.values

# %%
# Inspect the shape
print(data.shape)
# Out:
# (8190, 93)

# %%
# Inspect the shape
print(target.shape)
# Out:
# (8190,)

# %%
# Print the number of unique labels
number_digits = len(np.unique(target))

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Figure size (width, height) in inches
fig = plt.figure(figsize=(6, 6))

# Adjust the subplots 
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# For each of the 93 features
for i in range(93):
    # Initialize the subplots: add a subplot in the grid of 8 by 8, at the i+1-th position
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    # Display an image at the i-th position
    ax.plot(data[i])#, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(target[i]))

# Show the plot
plt.show()

# %%
from sklearn.decomposition import RandomizedPCA
# Create a Randomized PCA model that takes two components
randomized_pca = RandomizedPCA(n_components=2)
# Out:
# C:\Users\Angus\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class RandomizedPCA is deprecated; RandomizedPCA was deprecated in 0.18 and will be removed in 0.20. Use PCA(svd_solver='randomized') instead. The new implementation DOES NOT store whiten ``components_``. Apply transform to get them.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# Fit and transform the data to the model
reduced_data_rpca = randomized_pca.fit_transform(data)

# %%
reduced_data_rpca
# Out:
# array([[  95371.65783728,  -10916.22826155],
#        [ 113371.27354473,   -8371.71255289],
#        [ 106237.61722011,  -10158.22172003],
#        ...,
#        [ -47875.02513627,    8659.95460042],
#        [ -47886.18241699,    8803.48642519],
#        [ -47901.77014712,    9011.97167031]])

# %%
from sklearn.decomposition import PCA
# Create a regular PCA model 
pca = PCA(n_components=2)

# %%
# Fit and transform the data to the model
reduced_data_pca = pca.fit_transform(data)

# %%
# Inspect the shape
reduced_data_pca.shape
# Out:
# (8190, 2)

# %%
# Print out the data
print(reduced_data_rpca)
print(reduced_data_pca)
# Out:
# [[  95371.65783728  -10916.22826155]
#  [ 113371.27354473   -8371.71255289]
#  [ 106237.61722011  -10158.22172003]
#  ...,
#  [ -47875.02513627    8659.95460042]
#  [ -47886.18241699    8803.48642519]
#  [ -47901.77014712    9011.97167031]]
# [[  95371.66042469  -10915.96760685]
#  [ 113371.27264625   -8371.63609219]
#  [ 106237.63371778  -10158.32918513]
#  ...,
#  [ -47875.02524853    8659.95641783]
#  [ -47886.18219036    8803.47556273]
#  [ -47901.76894795    9011.92949533]]

# %%
colors = ['black', 'blue', 'purple', 'yellow', 'white', 'red', 'lime', 'cyan', 'orange', 'gray']
for i in range(len(colors)):
    x = reduced_data_rpca[:, 0][target == i]
    y = reduced_data_rpca[:, 1][target == i]
    plt.scatter(x, y, c=colors[i])
#plt.legend(target), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.title("PCA Scatter Plot")
plt.show()
