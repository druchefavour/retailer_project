# %% [markdown]
# ### 9.0.1 Collinearity
# In this section, we will be exploring the degree of correlation between the predictor variables in our retail sales dataset. That is, we will be testing the models collinearity. For two variables that are collinear, we expect that they should contain similar information about the variance within the given dataset.
#
# To detect the collinearity, we will create a correlation matrix and find variables with large absolute values.
#
# ### 9.0.2 Multicollinearity
# Detection of multicollinearity is follows a more complicated procedure. This is because it emerges when three or more variables which are highly correlated are included in the model. It can also emerge when isolated pairs of variables are not collinear.
#
# In order to test multicollinearity we will use Variance Infaltion Factor (VIF).
#
# ### 9.0.3 Variance Infaltion Factor
# The variance inflation factor (VIF) is a measure of colinearity among predictor variables within a multiple regression. It is calculated by taking the ration of the variance of all a given model's beta if it were fit alone.

# %% [markdown]
# ### 9.0.4 Steps for Implementing VIF
#
# 1. Run a multiple regression
# 2. Calculate the VIF Factors
# 3. Inspect the factors for each predictor variable: If the VIF is between 5-10, mul;ticollinearity is likely present and we would consider dropping the variable.
#
# Let us import the libraries required for analysis.

# %%
#imports
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ### 9.0.5 Data Import
# We will now import the dataset.

# %%
# load the master_dataset.xls
df = pd.read_excel('master_dataset.xlsx', sheetname='Sheet1')

# %% [markdown]
# ### 9.0.6 Data Manipulation
# We will drop all the non-numeric columns

# %%
# Drop Non-numeric cells
df.dropna()
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-05-02        42.31       2.572   10382.90    6115.67
# 1         1 2010-12-02        38.51       2.548   10382.90    6115.67
# 2         1 2010-02-19        39.93       2.514   10382.90    6115.67
# 3         1 2010-02-26        46.63       2.561   10382.90    6115.67
# 4         1 2010-05-03        46.50       2.625   10382.90    6115.67
# 5         1 2010-12-03        57.79       2.667   10382.90    6115.67
# 6         1 2010-03-19        54.58       2.720   10382.90    6115.67
# 7         1 2010-03-26        51.45       2.732   10382.90    6115.67
# 8         1 2010-02-04        62.27       2.719   10382.90    6115.67
# 9         1 2010-09-04        65.86       2.770   10382.90    6115.67
# 10        1 2010-04-16        66.32       2.808   10382.90    6115.67
# 11        1 2010-04-23        64.84       2.795   10382.90    6115.67
# 12        1 2010-04-30        67.41       2.780   10382.90    6115.67
# 13        1 2010-07-05        72.55       2.835   10382.90    6115.67
# 14        1 2010-05-14        74.78       2.854   10382.90    6115.67
# 15        1 2010-05-21        76.44       2.826   10382.90    6115.67
# 16        1 2010-05-28        80.44       2.759   10382.90    6115.67
# 17        1 2010-04-06        80.69       2.705   10382.90    6115.67
# 18        1 2010-11-06        80.43       2.668   10382.90    6115.67
# 19        1 2010-06-18        84.11       2.637   10382.90    6115.67
# 20        1 2010-06-25        84.34       2.653   10382.90    6115.67
# 21        1 2010-02-07        80.91       2.669   10382.90    6115.67
# 22        1 2010-09-07        80.48       2.642   10382.90    6115.67
# 23        1 2010-07-16        83.15       2.623   10382.90    6115.67
# 24        1 2010-07-23        83.36       2.608   10382.90    6115.67
# 25        1 2010-07-30        81.84       2.640   10382.90    6115.67
# 26        1 2010-06-08        87.16       2.627   10382.90    6115.67
# 18       215.07    2406.62    6551.42  211.456095     ...       70245.24
# 19       215.07    2406.62    6551.42  211.453772     ...       78840.85
# 20       215.07    2406.62    6551.42  211.338653     ...       77651.52
# 21       215.07    2406.62    6551.42  211.223533     ...       73325.44
# 22       215.07    2406.62    6551.42  211.108414     ...       76733.25
# 23       215.07    2406.62    6551.42  211.100385     ...       71934.19
# 24       215.07    2406.62    6551.42  211.235144     ...       71207.64
# 25       215.07    2406.62    6551.42  211.369903     ...       69626.13
# 26       215.07    2406.62    6551.42  211.504662     ...       78810.39
# 27       215.07    2406.62    6551.42  211.639421     ...       76608.54
# 28       215.07    2406.62    6551.42  211.603363     ...       72447.85
# 29       215.07    2406.62    6551.42  211.567306     ...       69272.76
# ...         ...        ...        ...         ...     ...            ...
# 8160       8.93      35.85    3682.17  192.659622     ...       23653.95
# 8161       3.81     152.18    2403.14  192.759980     ...       23653.95
# 8162       4.02     483.58    1467.78  192.809507     ...       23653.95
# 8163       0.20     332.68    1361.74  192.838701     ...       23653.95
# 8164     827.90   26424.02     700.93  192.867895     ...       23653.95
# 8165      78.26   24823.94    3233.44  192.897089     ...       23653.95
# 8166       0.36    5012.39    6411.71  192.943471     ...       23653.95
# 8167      23.38    1516.76    3061.21  193.032822     ...       23653.95
# 8168       5.60      27.55    1668.95  193.122173     ...       23653.95
# 8169      34.62    3096.92    3486.91  193.211524     ...       23653.95
# 8170      11.08     912.87    1360.36  193.296277     ...       23653.95
# 8171     308.00    1764.47    1647.31  193.369533     ...       23653.95
# 8172     350.84      53.90    1722.11  193.442790     ...       23653.95
# 8173     182.59    1523.83    1743.09  193.516047     ...       23653.95
# 8174      21.08    1302.31    1380.74  193.589304     ...       23653.95
# 8175      44.38      60.83    1445.05  193.589304     ...       23653.95
# 8176      57.52      40.51    2476.18  193.589304     ...       23653.95
# 8177      92.96    3580.32    2242.24  193.589304     ...       23653.95
# 8178      53.09     375.22    5738.20  193.589304     ...       23653.95
# 8179       6.12     522.70    2541.62  193.589304     ...       23653.95
# 8180      58.48    1183.23    1309.30  193.589304     ...       23653.95
# 8181      77.06       9.38    4227.27  193.589304     ...       23653.95
# 8182      80.00    4825.71    3597.34  193.589304     ...       23653.95
# 8183     348.54    2612.33    3459.39  193.589304     ...       23653.95
# 8184     178.56    2463.42    3117.94  193.589304     ...       23653.95
# 8185       3.00    2449.97    3169.69  193.589304     ...       23653.95
# 8186     582.74    5797.47    1514.93  193.589304     ...       23653.95
# 8187      85.72     744.84    2150.36  193.589304     ...       23653.95
# 8188     204.19     363.00    1059.46  193.589304     ...       23653.95
# 8189       2.06      10.88    1864.57  193.589304     ...       23653.95
#
#      Musical_Instruments  Star_Wars  Movies_TV  Video_Games  Portable_Audios  \
# 0               57022.45  118966.90   58034.24     56157.83        113009.41
# 1               57845.36  126907.41   63245.00     66172.11        111466.37
# 2               59462.22  122267.65   69962.56     62795.87        124821.44
# 3               63011.44  135066.75   62581.64     72212.32        107952.07
# 4               57335.17  125048.08   57630.02     55501.07        103652.58
store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0      1        42.31       2.572    10382.9    6115.67     215.07    2406.62
# 1      1        38.51       2.548    10382.9    6115.67     215.07    2406.62
# 2      1        39.93       2.514    10382.9    6115.67     215.07    2406.62
# 3      1        46.63       2.561    10382.9    6115.67     215.07    2406.62
# 4      1        46.50       2.625    10382.9    6115.67     215.07    2406.62
#
#    MarkDown5         CPI  Unemployment     ...          Books  \
# 0    6551.42  211.096358         8.106     ...       73315.81
# 1    6551.42  211.242170         8.106     ...       77280.42
# 2    6551.42  211.289143         8.106     ...       78602.71
# 3    6551.42  211.319643         8.106     ...       76091.36
# 4    6551.42  211.350143         8.106     ...       71718.48
#
#    Musical_Instruments  Star_Wars  Movies_TV  Video_Games  Portable_Audios  \
# 0             57022.45  118966.90   58034.24     56157.83        113009.41
# 1             57845.36  126907.41   63245.00     66172.11        111466.37
# 2             59462.22  122267.65   69962.56     62795.87        124821.44
# 3             63011.44  135066.75   62581.64     72212.32        107952.07
# 4             57335.17  125048.08   57630.02     55501.07        103652.58
#
#    Cameras_Camcoders  Auto_Electronics  Wearable_Tech  Smart_homes
# 0           27930.71          32954.82       10344.16         0.01
# 1            5265.09          30149.20       14740.14         0.01
# 2            5265.09          33726.13       10139.42         0.01
# 3           28420.73          31585.78       12087.95        20.00
# 4           28420.73          28457.31       10871.74        20.00
#
# [5 rows x 93 columns]

# %% [markdown]
# Let us use MarkDown1 as the target variable and the others as predictor variable and then run multiple regression. Firstly, let us create a duplicate dataframe and then we will drop the column "MarkDown1" which we will use as our target varibale from the duplicate dataframe.

# %%
target = df['MarkDown1']

# %%
# Duplicate dataframe and assign the name df_dup to it
df_dup = df

# %%
# Drop "Markdown1"
df_dup.drop(['MarkDown1'],  axis = 1, inplace=True)

# %% [markdown]
# ### 9.0.7 Numpy Array
# We will create two numpy arrays X, representing the predictor variables and y representing the target variables:

# %%
#Numpy array
X = df_dup.values
y = target.values

# %% [markdown]
# ### 9.0.8 Reshape Array
# We will now reshape the arrays in preparation for regression analysis

# %%
# Print the dimensions of X and y before reshaping
print("Dimensions of y before reshaping: {}".format(y.shape))
print("Dimensions of X before reshaping: {}".format(X.shape))
# Out:
# Dimensions of y before reshaping: (8190,)
# Dimensions of X before reshaping: (8190, 92)

# %%
# Reshape  the dimension of y
y = y.reshape(-1, 1)

# %% [markdown]
# ### 9.0.9 Multiple Regression

# %%
## fit a OLS model with intercept on the data set
X = sm.add_constant(X)

# %% [markdown]
# We will run linear regression models in SKLearn. SKLearn is pretty much the golden standard when it comes to machine learning in Python. In order to use linear regression, we need to import it:

# %%
from sklearn import linear_model

# %% [markdown]
# Then we’ll fit a model:

# %%
lm = linear_model.LinearRegression()

# %%
model = lm.fit(X,y)

# %% [markdown]
# The lm.fit() function fits a linear model. We want to use the model to make predictions, so we’ll use lm.predict():

# %%
predictions = lm.predict(X)

# %% [markdown]
# The print function would print the first 5 predictions for y (I didn’t print the entire list to “save room”. Removing [0:5] would print the entire list):

# %%
print((predictions)[0:5])
# Out:
# [[  7234.75615153]
#  [ 12361.17684614]
#  [ 12578.73163448]
#  [ 11702.03855637]
#  [  8002.05489265]]

# %% [markdown]
# Remember, lm.predict() predicts the y (dependent variable) using the linear model we fitted. We use built-in functions to return the score, the coefficients and the estimated intercepts

# %%
lm.score(X,y)
# Out:
# 0.6857431849075899

# %%
lm.coef_
# Out:
# array([[ -1.13921338e-10,   1.20500336e+02,  -1.27638829e+00,
#          -3.53095573e+02,   1.35663608e-01,  -6.41334627e-02,
#           1.10872046e+00,   6.30729742e-03,  -1.05537392e-02,
#           5.98986987e+01,   7.96124877e+02,   3.54716258e-02,
#          -1.85512385e-02,  -8.98316094e-02,  -1.03114195e-03,
#           3.20915222e-01,  -9.44050332e-03,   1.40405164e-01,
#           1.57409274e-02,  -3.93847773e-02,  -6.76029606e-03,
#           1.38345898e-01,   1.28062377e-02,  -2.59795512e-01,
#           1.70205423e-01,  -2.92213411e-01,   4.88036516e-03,
#           1.30569333e-01,  -1.06646088e-02,   5.44034030e-02,
#          -1.99629574e-01,   4.70159307e-01,  -6.87432790e-02,
#          -2.19933174e-02,  -2.31341208e-01,  -7.68720506e-02,
#          -1.22479278e-01,   8.30781434e-01,  -2.57322650e+00,
#          -2.90807838e-02,   4.20582519e-01,  -1.12719850e-01,
#           1.13657487e-01,   3.17410244e-01,  -2.16439259e-02,
#           7.78665468e-03,  -7.74034552e-02,  -1.53960471e-01,
#          -2.84977618e-02,   6.86434142e+00,  -1.04606334e-01,
#           1.35171350e-01,   3.74275659e-01,  -4.59589344e+02,
#           4.16970879e-01,  -1.24141995e+01,  -5.10904426e-02,
#          -1.00340194e+00,  -4.55342835e-01,   1.21300333e-01,
#          -7.00516050e-01,  -1.11539534e+01,  -1.61794289e-01,
#          -1.06479078e+00,   1.07291244e-01,   7.91673151e-02,
#          -1.77869675e-02,  -1.87295597e-01,   1.42688213e+00,
#           1.45609203e-01,   2.73655731e-02,  -4.41814784e-01,
#           9.19343110e-03,   6.91668921e-02,  -6.83836132e-01,
#          -5.78607329e+00,   5.16507505e-02,  -2.54192685e-01,
#          -1.46410431e-01,  -2.52063989e-02,   6.91013875e-02,
#          -6.58030764e-02,  -2.49091516e-02,   5.59529890e-02,
#           1.10591213e-02,   2.48810661e-02,   3.76108731e-02,
#           1.17825357e-02,  -7.06018411e-02,  -8.68429281e-03,
#          -1.55467396e-01,  -5.89007344e-02,  -1.07868396e-01]])

# %%
lm.intercept_
# Out:
# array([-4236.86232933])

# %% [markdown]
# These are all (estimated/predicted) parts of the multiple regression equation

# %% [markdown]
# ### 9.0.10 Generating VIF

# %%
# load the master_dataset.xls
df = pd.read_excel('master_dataset.xlsx', sheetname='Sheet1')

# %%
#subset the dataframe
df = df[['MarkDown1','MarkDown2','MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment']].dropna()

# %% [markdown]
# #### 9.0.10.1 Run Multiple Regression

# %%
# Run Multiple Regression
#%%capture
#gather features
features = "+".join(df.columns)

# %%
# get y and X dataframes based on this regression:
y, X = dmatrices('MarkDown1 ~' + features, df, return_type='dataframe')

# %% [markdown]
# #### 9.0.10.2 Calculate VIF Factors

# %%
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)
# Out:
#    VIF Factor      features
# 0        56.7     Intercept
# 1         2.4     MarkDown1
# 2         1.2     MarkDown2
# 3         1.0     MarkDown3
# 4         2.2     MarkDown4
# 5         1.0     MarkDown5
# 6         1.1           CPI
# 7         1.1  Unemployment

# %%
# load the master_dataset.xls
df = pd.read_excel('master_dataset.xlsx', sheetname='Sheet1')

# %%
# Drop Non-Numeric Columns
df = df._get_numeric_data()

# %%
df.keys()
# Out:
# Index(['Store', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday', 'Size', 'Jewelry', 'Pets', 'TV_Video', 'Cell_Phones',
#        'Pharmaceutical ', 'Health_beauty', 'Toy ', 'Home_others', 'Kitchen',
#        'Bedding', 'Bathroom', 'Office_supplies ', 'School_Supplies',
#        'Home_Office', 'Craft_general', 'Floral', 'Beading', 'Paint', 'Framing',
#        'outdoor', 'Auto', 'School_Uniforms', 'Baby_Toddlers_Clothing',
#        'Baby_Kids_Shoes', 'Clearance_Clothings', 'Boys_Clothing',
#        'Girls_Clothing', 'Women_Clothing', 'Intimates_Sleepwears',
#        'Men_Clothings', 'Precious_Metals', 'Active_Wear', 'Adult_Shoes',
#        'Bags_Accessories', 'Sportswear', 'Computer', 'Music', 'Luggage',
#        'Food', 'Fruit', 'Grocery', 'Laundry', 'IPad_Tablets',
#        'Heating_Cooling', 'Swim_Shop', 'Gift_cards', 'Baby_Essentials',
#        'Cribs', 'Car_Seats', 'Strollers', 'Bikes', 'Photo',
#        'Household_Essentials', 'Air_Quality', 'Light_bulbs', 'Gardening',
#        'Building_Materials', 'Hardware', 'Electrical', 'Home_Safety', 'Tools',
#        'Teen_Room', 'Kids_Room', 'Lighting', 'Home_Decor', 'Mattresses',
#        'Furniture', 'Storage', 'Appliances', 'Pioneer_Woman',
#        'Computer_Software', 'Books', 'Musical_Instruments', 'Star_Wars',
#        'Movies_TV', 'Video_Games', 'Portable_Audios', 'Cameras_Camcoders',
#        'Auto_Electronics', 'Wearable_Tech', 'Smart_homes'],
#       dtype='object')

# %%
df[['Toy']] = df[['Toy ']]

# %%
df[['Pharmaceutical']] = df[['Pharmaceutical ']]

# %%
df[['Office_supplies']] = df[['Office_supplies ']]

# %%
df = df[['MarkDown1', 'Store', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5', 
         'CPI', 'Unemployment', 'Size', 'Jewelry', 'Pets', 'TV_Video', 'Cell_Phones', 'Pharmaceutical', 'Health_beauty', 'Toy',
         'Home_others', 'Kitchen', 'Bedding', 'Bathroom', 'Office_supplies', 'School_Supplies', 'Home_Office', 'Craft_general',
         'Floral','Beading', 'Paint', 'Framing', 'outdoor', 'Auto', 'School_Uniforms', 'Baby_Toddlers_Clothing', 'Baby_Kids_Shoes',
         'Clearance_Clothings', 'Boys_Clothing', 'Girls_Clothing', 'Women_Clothing', 'Intimates_Sleepwears', 'Men_Clothings',
         'Precious_Metals', 'Active_Wear', 'Adult_Shoes', 'Bags_Accessories', 'Sportswear', 'Computer', 'Music', 'Luggage',
         'Food', 'Fruit', 'Grocery', 'Laundry', 'IPad_Tablets', 'Heating_Cooling', 'Swim_Shop', 'Gift_cards', 'Baby_Essentials',
         'Cribs', 'Car_Seats', 'Strollers', 'Bikes', 'Photo', 'Household_Essentials', 'Air_Quality', 'Light_bulbs', 'Gardening',
         'Building_Materials', 'Hardware', 'Electrical', 'Home_Safety', 'Tools', 'Teen_Room', 'Kids_Room', 'Lighting', 
         'Home_Decor', 'Mattresses', 'Furniture', 'Storage', 'Appliances', 'Pioneer_Woman', 'Computer_Software', 'Books', 
         'Musical_Instruments', 'Star_Wars', 'Movies_TV', 'Video_Games', 'Portable_Audios', 'Cameras_Camcoders', 
         'Auto_Electronics', 'Wearable_Tech', 'Smart_homes']].dropna()

# %%
# Run Multiple Regression
#%%capture
#gather features
features = "+".join(df.columns)

# %%
# get y and X dataframes based on this regression:
y, X = dmatrices('MarkDown1 ~' + features, df, return_type='dataframe')

# %%
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
# Out:
# C:\Users\Angus\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)

# %%
vif.round(1)
# Out:
#      VIF Factor              features
# 0   2053.400000             Intercept
# 1           inf          MarkDown1[0]
# 2           inf          MarkDown1[1]
# 3     25.200000                 Store
# 4      1.300000           Temperature
# 5      1.200000            Fuel_Price
# 6      1.600000             MarkDown2
# 7      1.000000             MarkDown3
# 8      2.600000             MarkDown4
# 9      1.100000             MarkDown5
# 10     1.900000                   CPI
# 11     1.800000          Unemployment
# 12     2.200000                  Size
# 13     4.100000               Jewelry
# 14   120.100000                  Pets
# 15     8.200000              TV_Video
# 16    76.300000           Cell_Phones
# 17    18.900000        Pharmaceutical
# 18     9.700000         Health_beauty
# 19    19.600000                   Toy
# 20    26.100000           Home_others
# 21     8.400000               Kitchen
# 22    23.700000               Bedding
# 23     4.900000              Bathroom
# 24    10.800000       Office_supplies
# 25    88.600000       School_Supplies
# 26    44.600000           Home_Office
# 27    11.000000         Craft_general
# 28    32.900000                Floral
# 29     3.000000               Beading
# ..          ...                   ...
# 64     2.200000                 Photo
# 65    15.700000  Household_Essentials
# 66     3.500000           Air_Quality
# 67     2.900000           Light_bulbs
# 68     4.400000             Gardening
# 69     2.300000    Building_Materials
# 70     7.300000              Hardware
# 71     6.700000            Electrical
# 72    11.400000           Home_Safety
# 73    11.400000                 Tools
# 74    31.900000             Teen_Room
# 75     1.800000             Kids_Room
# 76     1.500000              Lighting
# 77    17.600000            Home_Decor
# 78    25.100000            Mattresses
# 79    45.500000             Furniture
# 80    17.300000               Storage
# 81    11.300000            Appliances
# 82     5.700000         Pioneer_Woman
# 83     7.700000     Computer_Software
# 84   134.300000                 Books
# 85    60.700000   Musical_Instruments
# 86   116.600000             Star_Wars
# 87    21.200000             Movies_TV
# 88    32.800000           Video_Games
# 89    89.000000       Portable_Audios
# 90     6.800000     Cameras_Camcoders
# 91    46.200000      Auto_Electronics
# 92    21.900000         Wearable_Tech
# 93     1.400000           Smart_homes
#
# [94 rows x 2 columns]
